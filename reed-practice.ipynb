# %%
import pandas as pd
cost_of_living_file = "/home/reedandrew18/global_cost_of_living/data/cost-of-living.csv"
cost_df = pd.read_csv(cost_of_living_file, header=0)
cost_df.head()
# Out:
#    No.      city      country    x1     x2    x3    x4    x5    x6    x7  ...  \
# 0    0     Delhi        India  4.90  22.04  4.28  1.84  3.67  1.78  0.48  ...
# 1    1  Shanghai        China  5.59  40.51  5.59  1.12  4.19  3.96  0.52  ...
# 2    2   Jakarta    Indonesia  2.54  22.25  3.50  2.02  3.18  2.19  0.59  ...
# 3    3    Manila  Philippines  3.54  27.40  3.54  1.24  1.90  2.91  0.93  ...
# 4    4     Seoul  South Korea  7.16  52.77  6.03  3.02  4.52  3.86  1.46  ...
#
#       x47      x48     x49      x50      x51       x52       x53      x54  \
# 0   36.26   223.87  133.38   596.16   325.82   2619.46   1068.90   586.35
# 1  121.19  1080.07  564.30  2972.57  1532.23  17333.09   9174.88  1382.83
# 2   80.32   482.85  270.15  1117.69   584.37   2694.05   1269.44   483.19
# 3   61.82   559.52  281.78  1754.40   684.81   3536.04   2596.44   419.02
# 4  108.30   809.83  583.60  2621.05  1683.74  21847.94  10832.90  2672.23
#
#     x55  data_quality
# 0  7.96             1
# ...

# %%
#rename all the columns
cost_df = cost_df.rename(columns={'x33': 'Gasoline (1 liter) (USD)', 'x48': 'Apartment (1 bedroom) in City Centre (USD)', 'x49': 'Apartment (1 bedroom) Outside of Centre (USD)', 'x50': 'Apartment (3 bedrooms) in City Centre (USD)', 'x51': 'Apartment (3 bedrooms) Outside of Centre (USD)'})
cost_df['Gasoline (1 liter) (USD)']
# Out:
# 0       1.25
# 1       1.17
# 2       0.79
# 3       1.38
# 4       1.41
#         ...
# 4869     NaN
# 4870     NaN
# 4871    1.01
# 4872     NaN
# 4873     NaN
# Name: Gasoline (1 liter) (USD), Length: 4874, dtype: float64

# %%
cost_df.sort_values(by=['city','country'])
# Out:
#        No.              city               country     x1     x2     x3    x4  \
# 2147  2147  's-Hertogenbosch           Netherlands  18.70  62.32   8.98  4.28
# 1439  1439          A Coruna                 Spain  11.43  45.18   7.27  1.87
# 1437  1437            Aachen               Germany  10.39  51.93   8.57  3.64
# 2245  2245           Aalborg               Denmark  18.16  90.78  11.17  6.98
# 3715  3715             Aalen               Germany  15.58  51.93  10.39  3.64
# ...    ...               ...                   ...    ...    ...    ...   ...
# 2242  2242            Zwolle           Netherlands  15.58  62.32   8.31  5.25
# 4158  4158            `Afrin                 Syria   5.98  37.35    NaN  2.49
# 898    898            `Ajman  United Arab Emirates   3.40  32.67   6.81  8.85
# 3038  3038             `Ataq                 Yemen    NaN    NaN    NaN   NaN
# 2508  2508             `Ibri                  Oman   2.60  38.96   6.49  5.19
#
# ...

# %%
lat_lon_file = '/home/reedandrew18/global_cost_of_living/data/world_country_and_usa_states_latitude_and_longitude_values.csv'
lat_lon = pd.read_csv(lat_lon_file, header=0)
lat_lon.head()
# Out:
#   country_code   latitude  longitude               country usa_state_code  \
# 0           AD  42.546245   1.601554               Andorra             AK
# 1           AE  23.424076  53.847818  United Arab Emirates             AL
# 2           AF  33.939110  67.709953           Afghanistan             AR
# 3           AG  17.060816 -61.796428   Antigua and Barbuda             AZ
# 4           AI  18.220554 -63.068615              Anguilla             CA
#
#    usa_state_latitude  usa_state_longitude   usa_state
# 0           63.588753          -154.493062      Alaska
# 1           32.318231           -86.902298     Alabama
# 2           35.201050           -91.831833    Arkansas
# 3           34.048928          -111.093731     Arizona
# 4           36.778261          -119.417932  California

# %%
drop_cols = ['country_code','usa_state_code','usa_state_latitude','usa_state_longitude','usa_state']
lat_lon.drop(drop_cols, inplace=True, axis=1)
lat_lon.head()
# Out:
#     latitude  longitude               country
# 0  42.546245   1.601554               Andorra
# 1  23.424076  53.847818  United Arab Emirates
# 2  33.939110  67.709953           Afghanistan
# 3  17.060816 -61.796428   Antigua and Barbuda
# 4  18.220554 -63.068615              Anguilla
